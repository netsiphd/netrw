# %%
from global_rewiring import GlobalRewiring
import networkx as nx
import random

# %%
G = nx.DiGraph()
G.add_edges_from([[0,1],[1,2],[2,3],[3,4],[4,0],[2,0],[3,0]])

# %%
obj = GlobalRewiring()

# %%
new_G = obj.global_edge_rewiring(G,p=.3,timesteps=100)

# %%
type(new_G)
# Out:
# networkx.classes.digraph.DiGraph

# %%
nx.draw(new_G,with_labels=True)

# %%
len(G.edges())
# Out:
# 7

# %%
len(new_G.edges())
# Out:
# 7

# %%
nx.spectral_layout(G)
# Out:
# {0: array([-7.20718069e-17,  2.20929258e-16]),
#  1: array([-1.        ,  0.76536686]),
#  2: array([-0.41421356, -0.76536686]),
#  3: array([ 0.41421356, -0.76536686]),
#  4: array([1.        , 0.76536686])}
